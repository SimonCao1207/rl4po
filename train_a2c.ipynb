# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
# %matplotlib inline
from finrl.config_tickers import SP_500_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from settings import *
from pprint import pprint
import sys
import os
import itertools
import json

if not os.path.exists(RESULTS_DIR):
    os.mkdir(RESULTS_DIR)

sys.path.append("../FinRL-Library")

# %%
INDICATORS = ['macd',
               'rsi_30',
               'cci_30',
               'dx_30']

with open("data/stock.json") as f:
    list_tickers = list(json.load(f).keys())

# %%
# df = YahooDownloader(start_date = TRAIN_START_DATE,
                     # end_date = TEST_END_DATE,
                     # ticker_list = list_tickers).fetch_data()

df = pd.read_csv("data/full_data.csv", index_col=0)
df.head()

# %%
processed = pd.read_csv("df_processed.csv")
processed.sort_values(['date','tic'],ignore_index=True).tail(10)
# Out:
#         Unnamed: 0        date        open        high         low  \
# 251690      251690  2021-12-29   78.199997   78.639999   77.769997
# 251691      251691  2021-12-29  504.779999  507.220001  502.000000
# 251692      251692  2021-12-29   41.680000   41.820000   41.180000
# 251693      251693  2021-12-29  253.639999  256.570007  253.289993
# 251694      251694  2021-12-29   51.450001   52.310001   51.279999
# 251695      251695  2021-12-29   96.650002   97.089996   96.349998
# 251696      251696  2021-12-29  230.070007  234.360001  230.070007
# 251697      251697  2021-12-29  165.610001  166.860001  164.940002
# 251698      251698  2021-12-29  465.000000  470.480011  462.950012
# 251699      251699  2021-12-29  124.349518  125.621361  124.019417
#
#              close   volume   tic  day       macd     rsi_30      cci_30  \
# 251690   73.107864  1122400   SYY    2   0.530034  53.760107  159.147158
# 251691  489.852081  1573900   UNH    2  13.187855  68.767843  127.791454
# 251692   37.804081   580100   VNO    2  -0.367866  47.954637  -26.616039
# 251693  255.929993   325900  VRSN    2   4.372965  64.742318  280.638795
# 251694   45.432167  5117300   WBA    2   0.853457  61.200644  156.908726
# 251695   88.928246   556700   WEC    2   1.363637  58.682591  108.633868
# 251696  204.420471   275400   WHR    2   1.604235  56.181706   69.907236
# 251697  160.313568   773100    WM    2   0.586869  57.280689  139.208305
# 251698  465.271881   219400   WST    2   8.414886  59.415887  188.021952
# 251699  122.284866  2508771   ZBH    2  -1.090622  46.150884   59.872990
#
#             dx_30  turbulence
# 251690  16.522302    16.99864
# 251691  45.467053    16.99864
# 251692  15.883827    16.99864
# 251693  45.329009    16.99864
# 251694  36.986792    16.99864
# 251695  36.199452    16.99864
# 251696   8.773698    16.99864
# 251697  22.267360    16.99864
# 251698  25.899134    16.99864
# 251699   6.069951    16.99864

# %% [markdown]
# ## Train/Test split

# %%
train = data_split(processed, TRAIN_START_DATE, TRAIN_END_DATE)
trade = data_split(processed, TEST_START_DATE, TEST_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 201400
# 50300

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 50, State Space: 301

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
e_train_gym = StockTradingEnv(df = train, **env_kwargs)
agent = DRLAgent(e_train_gym)
if_using_a2c = True
model_a2c = agent.get_model("a2c")

trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | time/                 |           |
# |    fps                | 59        |
# |    iterations         | 100       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -70.9     |
# |    explained_variance | 0.0535    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -33.9     |
# |    reward             | 1.0868909 |
# |    std                | 0.999     |
# |    value_loss         | 2.06      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 58        |
# |    iterations         | 200       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -70.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 36        |
# |    reward             | 0.8124844 |
# |    std                | 0.999     |
# |    value_loss         | 0.474     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 57       |
# |    iterations         | 300      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -71      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 413      |
# |    reward             | -4.05451 |
# |    std                | 1        |
# |    value_loss         | 42.2     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 57          |
# |    iterations         | 400         |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -71.1       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -79.5       |
# |    reward             | -0.34148505 |
# |    std                | 1           |
# |    value_loss         | 3.13        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 57       |
# |    iterations         | 500      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -71.1    |
# |    explained_variance | 0.05     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 163      |
# |    reward             | 2.524114 |
# |    std                | 1        |
# |    value_loss         | 27       |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 57         |
# |    iterations         | 600        |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -71.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 192        |
# |    reward             | -1.4993396 |
# |    std                | 1          |
# |    value_loss         | 9.94       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 700       |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -71.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 753       |
# |    reward             | 3.0697637 |
# |    std                | 1.01      |
# |    value_loss         | 123       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 800       |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -71.2     |
# |    explained_variance | -0.00528  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -5.3      |
# |    reward             | 2.0903447 |
# |    std                | 1.01      |
# |    value_loss         | 9.58      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 711       |
# | time/                 |           |
# |    fps                | 58        |
# |    iterations         | 900       |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -71.2     |
# |    explained_variance | 0.0195    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 77.7      |
# |    reward             | -1.509222 |
# |    std                | 1.01      |
# |    value_loss         | 1.75      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 711       |
# | time/                 |           |
# |    fps                | 58        |
# |    iterations         | 1000      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -71.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 347       |
# |    reward             | 1.3607595 |
# |    std                | 1.01      |
# |    value_loss         | 27.6      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 711       |
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 1100      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -71.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -126      |
# |    reward             | 4.5394187 |
# |    std                | 1.01      |
# |    value_loss         | 5.31      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 711        |
# | time/                 |            |
# |    fps                | 57         |
# |    iterations         | 1200       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -71.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -126       |
# |    reward             | -3.1046717 |
# |    std                | 1.01       |
# |    value_loss         | 4.93       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 711        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 1300       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -71.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 155        |
# |    reward             | -4.0848484 |
# |    std                | 1.01       |
# |    value_loss         | 10         |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 711      |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 1400     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -71.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 233      |
# |    reward             | 2.706011 |
# |    std                | 1.01     |
# |    value_loss         | 43.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 711       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 1500      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -71.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 355       |
# |    reward             | 2.4738085 |
# |    std                | 1.01      |
# |    value_loss         | 34.7      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 711       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 1600      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -71.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 1.26e+03  |
# |    reward             | 4.5492425 |
# |    std                | 1.01      |
# |    value_loss         | 382       |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 715        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 1700       |
# |    time_elapsed       | 149        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -71.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -149       |
# |    reward             | 0.30643243 |
# |    std                | 1.01       |
# |    value_loss         | 5.26       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 715        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 1800       |
# |    time_elapsed       | 158        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -71.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -97.8      |
# |    reward             | 0.33357432 |
# |    std                | 1.01       |
# |    value_loss         | 6.19       |
# --------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 4.03e+03      |
# |    ep_rew_mean        | 715           |
# | time/                 |               |
# |    fps                | 56            |
# |    iterations         | 1900          |
# |    time_elapsed       | 167           |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -71.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1899          |
# |    policy_loss        | 212           |
# |    reward             | -0.0061465846 |
# |    std                | 1.01          |
# |    value_loss         | 19.2          |
# -----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 715         |
# | time/                 |             |
# |    fps                | 56          |
# |    iterations         | 2000        |
# |    time_elapsed       | 176         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -71.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 161         |
# |    reward             | 0.083832204 |
# |    std                | 1.01        |
# |    value_loss         | 5.57        |
# ---------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 715      |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 2100     |
# |    time_elapsed       | 185      |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -71.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -58.7    |
# |    reward             | 3.332667 |
# |    std                | 1.01     |
# |    value_loss         | 16.1     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 715       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 2200      |
# |    time_elapsed       | 193       |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -71.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 221       |
# |    reward             | -1.171929 |
# |    std                | 1.01      |
# |    value_loss         | 12.1      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 715       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 2300      |
# |    time_elapsed       | 202       |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -71.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 386       |
# |    reward             | 7.1770635 |
# |    std                | 1.01      |
# |    value_loss         | 81.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 715       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 2400      |
# |    time_elapsed       | 210       |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -71.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -369      |
# |    reward             | 1.3806108 |
# |    std                | 1.01      |
# |    value_loss         | 28.6      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 639       |
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 2500      |
# |    time_elapsed       | 219       |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -71.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 77.6      |
# |    reward             | 0.4669702 |
# |    std                | 1.01      |
# |    value_loss         | 1.93      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 639        |
# | time/                 |            |
# |    fps                | 57         |
# |    iterations         | 2600       |
# |    time_elapsed       | 227        |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -71.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 93.7       |
# |    reward             | 0.32205072 |
# |    std                | 1.01       |
# |    value_loss         | 2.39       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 639       |
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 2700      |
# |    time_elapsed       | 236       |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -71.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -32.3     |
# |    reward             | 3.2277243 |
# |    std                | 1.01      |
# |    value_loss         | 9.37      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 639       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 2800      |
# |    time_elapsed       | 245       |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -71.8     |
# |    explained_variance | 4.52e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 196       |
# |    reward             | 0.9295338 |
# |    std                | 1.02      |
# |    value_loss         | 11.3      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 639      |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 2900     |
# |    time_elapsed       | 254      |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -71.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -417     |
# |    reward             | -3.15223 |
# |    std                | 1.02     |
# |    value_loss         | 55.1     |
# ------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 639         |
# | time/                 |             |
# |    fps                | 57          |
# |    iterations         | 3000        |
# |    time_elapsed       | 262         |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -71.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | -157        |
# |    reward             | -0.41785297 |
# |    std                | 1.02        |
# |    value_loss         | 11.3        |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 639       |
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 3100      |
# |    time_elapsed       | 271       |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -71.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -319      |
# |    reward             | 2.8156374 |
# |    std                | 1.02      |
# |    value_loss         | 22.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 639       |
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 3200      |
# |    time_elapsed       | 280       |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -71.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 436       |
# |    reward             | 6.5169425 |
# |    std                | 1.02      |
# |    value_loss         | 47.2      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 638        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 3300       |
# |    time_elapsed       | 289        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -71.8      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | -42.2      |
# |    reward             | 0.48126096 |
# |    std                | 1.02       |
# |    value_loss         | 1.82       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 638       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 3400      |
# |    time_elapsed       | 298       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -71.8     |
# |    explained_variance | -4.55     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -76.5     |
# |    reward             | 1.2030588 |
# |    std                | 1.02      |
# |    value_loss         | 1.62      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 638        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 3500       |
# |    time_elapsed       | 307        |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -71.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 149        |
# |    reward             | -2.2030015 |
# |    std                | 1.02       |
# |    value_loss         | 6.05       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 638        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 3600       |
# |    time_elapsed       | 317        |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -71.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | 204        |
# |    reward             | -4.2031283 |
# |    std                | 1.02       |
# |    value_loss         | 11.3       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 638       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 3700      |
# |    time_elapsed       | 326       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -71.9     |
# |    explained_variance | 0.000398  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -85       |
# |    reward             | 1.8092912 |
# |    std                | 1.02      |
# |    value_loss         | 4.78      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 638        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 3800       |
# |    time_elapsed       | 335        |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -71.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | 292        |
# |    reward             | -3.9603329 |
# |    std                | 1.02       |
# |    value_loss         | 20.2       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 638       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 3900      |
# |    time_elapsed       | 344       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -72       |
# |    explained_variance | 0.0942    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 298       |
# |    reward             | 3.6145802 |
# |    std                | 1.02      |
# |    value_loss         | 20.3      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 638      |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 4000     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -72      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 292      |
# |    reward             | 3.409404 |
# |    std                | 1.02     |
# |    value_loss         | 43.6     |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 597        |
# | time/                 |            |
# |    fps                | 56         |
# |    iterations         | 4100       |
# |    time_elapsed       | 363        |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -72        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 99.6       |
# |    reward             | -1.6446493 |
# |    std                | 1.02       |
# |    value_loss         | 3.34       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 597       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 4200      |
# |    time_elapsed       | 372       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -72.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -151      |
# |    reward             | 0.7485423 |
# |    std                | 1.02      |
# |    value_loss         | 4.38      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 597       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 4300      |
# |    time_elapsed       | 382       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -72.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -14.8     |
# |    reward             | 2.3215683 |
# |    std                | 1.02      |
# |    value_loss         | 0.396     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 597       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 4400      |
# |    time_elapsed       | 391       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -72.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -470      |
# |    reward             | -1.113255 |
# |    std                | 1.02      |
# |    value_loss         | 62.8      |
# -------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 4.03e+03     |
# |    ep_rew_mean        | 597          |
# | time/                 |              |
# |    fps                | 56           |
# |    iterations         | 4500         |
# |    time_elapsed       | 401          |
# |    total_timesteps    | 22500        |
# | train/                |              |
# |    entropy_loss       | -72.1        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4499         |
# |    policy_loss        | 105          |
# |    reward             | -0.101036265 |
# |    std                | 1.02         |
# |    value_loss         | 2.63         |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 597       |
# | time/                 |           |
# |    fps                | 56        |
# |    iterations         | 4600      |
# |    time_elapsed       | 410       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -72.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 282       |
# |    reward             | 4.2608275 |
# |    std                | 1.03      |
# |    value_loss         | 24.1      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 597      |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 4700     |
# |    time_elapsed       | 418      |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -72.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -42.4    |
# |    reward             | 3.488586 |
# |    std                | 1.03     |
# |    value_loss         | 6.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 597      |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 4800     |
# |    time_elapsed       | 428      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -72.2    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 777      |
# |    reward             | 2.942707 |
# |    std                | 1.03     |
# |    value_loss         | 159      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 582      |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 4900     |
# |    time_elapsed       | 438      |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -72.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 170      |
# |    reward             | 1.533753 |
# |    std                | 1.03     |
# |    value_loss         | 6.3      |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 582        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 5000       |
# |    time_elapsed       | 447        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -72.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -264       |
# |    reward             | -1.1667545 |
# |    std                | 1.03       |
# |    value_loss         | 13.6       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 582       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5100      |
# |    time_elapsed       | 457       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -72.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 25.2      |
# |    reward             | 1.7717443 |
# |    std                | 1.03      |
# |    value_loss         | 0.641     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 582       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5200      |
# |    time_elapsed       | 467       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -72.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 149       |
# |    reward             | -3.279488 |
# |    std                | 1.03      |
# |    value_loss         | 11.7      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 582       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5300      |
# |    time_elapsed       | 476       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -72.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 217       |
# |    reward             | 1.9972775 |
# |    std                | 1.03      |
# |    value_loss         | 9.48      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 582       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5400      |
# |    time_elapsed       | 485       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -72.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | 19.1      |
# |    reward             | 3.2001483 |
# |    std                | 1.03      |
# |    value_loss         | 2.28      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 582       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5500      |
# |    time_elapsed       | 495       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -72.4     |
# |    explained_variance | 0.228     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -84.1     |
# |    reward             | 2.9962223 |
# |    std                | 1.03      |
# |    value_loss         | 2         |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 582      |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 5600     |
# |    time_elapsed       | 504      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -72.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 133      |
# |    reward             | 1.096001 |
# |    std                | 1.03     |
# |    value_loss         | 8.85     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 559       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5700      |
# |    time_elapsed       | 513       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -72.3     |
# |    explained_variance | 0.108     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -207      |
# |    reward             | 0.4125554 |
# |    std                | 1.03      |
# |    value_loss         | 9.72      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 559       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 5800      |
# |    time_elapsed       | 522       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -72.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 139       |
# |    reward             | 1.0827272 |
# |    std                | 1.03      |
# |    value_loss         | 4.65      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 559        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 5900       |
# |    time_elapsed       | 531        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -72.3      |
# |    explained_variance | 0.164      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | -340       |
# |    reward             | 0.18906258 |
# |    std                | 1.03       |
# |    value_loss         | 25.1       |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 559      |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 6000     |
# |    time_elapsed       | 541      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -72.2    |
# |    explained_variance | -0.137   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -146     |
# |    reward             | 2.595358 |
# |    std                | 1.03     |
# |    value_loss         | 16.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 559       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 6100      |
# |    time_elapsed       | 550       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -72.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | 102       |
# |    reward             | 2.8842518 |
# |    std                | 1.03      |
# |    value_loss         | 2.81      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 559       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 6200      |
# |    time_elapsed       | 559       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -72.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -15.9     |
# |    reward             | 1.1928394 |
# |    std                | 1.03      |
# |    value_loss         | 0.326     |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 559        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 6300       |
# |    time_elapsed       | 568        |
# |    total_timesteps    | 31500      |
# | train/                |            |
# |    entropy_loss       | -72.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | 293        |
# |    reward             | 0.53739536 |
# |    std                | 1.03       |
# |    value_loss         | 20.6       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 559       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 6400      |
# |    time_elapsed       | 578       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -72.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 221       |
# |    reward             | 3.9262466 |
# |    std                | 1.03      |
# |    value_loss         | 12.6      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 552        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 6500       |
# |    time_elapsed       | 587        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -72.6      |
# |    explained_variance | -2.34      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | -12.3      |
# |    reward             | -1.0167406 |
# |    std                | 1.03       |
# |    value_loss         | 4.76       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 552       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 6600      |
# |    time_elapsed       | 596       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -72.6     |
# |    explained_variance | -0.169    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -55       |
# |    reward             | 1.7092724 |
# |    std                | 1.04      |
# |    value_loss         | 3.07      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 552        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 6700       |
# |    time_elapsed       | 606        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -72.6      |
# |    explained_variance | -1.63      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | 15.4       |
# |    reward             | 0.17846487 |
# |    std                | 1.04       |
# |    value_loss         | 0.699      |
# --------------------------------------
# --------------------------------------
# ...
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 181       |
# |    reward             | 0.9411113 |
# |    std                | 1.05      |
# |    value_loss         | 6.5       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | 506      |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 8000     |
# |    time_elapsed       | 724      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -73.2    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 647      |
# |    reward             | 2.027636 |
# |    std                | 1.05     |
# |    value_loss         | 118      |
# ------------------------------------
# day: 4027, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5740830.26
# total_reward: 4740830.26
# total_cost: 36301.50
# total_trades: 115554
# Sharpe: 0.622
# =================================
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 502       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 8100      |
# |    time_elapsed       | 732       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -73.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -44.2     |
# |    reward             | 1.4393698 |
# |    std                | 1.05      |
# |    value_loss         | 1.51      |
# -------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 4.03e+03     |
# |    ep_rew_mean        | 502          |
# | time/                 |              |
# |    fps                | 55           |
# |    iterations         | 8200         |
# |    time_elapsed       | 741          |
# |    total_timesteps    | 41000        |
# | train/                |              |
# |    entropy_loss       | -73.3        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8199         |
# |    policy_loss        | 84.1         |
# |    reward             | -0.061009537 |
# |    std                | 1.05         |
# |    value_loss         | 1.46         |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 502       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 8300      |
# |    time_elapsed       | 749       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -73.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -32.7     |
# |    reward             | -1.580268 |
# |    std                | 1.05      |
# |    value_loss         | 1.65      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 502        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 8400       |
# |    time_elapsed       | 757        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -73.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | -439       |
# |    reward             | 0.36761415 |
# |    std                | 1.05       |
# |    value_loss         | 44         |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 502         |
# | time/                 |             |
# |    fps                | 55          |
# |    iterations         | 8500        |
# |    time_elapsed       | 766         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -73.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | -116        |
# |    reward             | -0.09358072 |
# |    std                | 1.05        |
# |    value_loss         | 2.97        |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 502       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 8600      |
# |    time_elapsed       | 774       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -73.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -15.7     |
# |    reward             | 1.8204764 |
# |    std                | 1.05      |
# |    value_loss         | 0.579     |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 502        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 8700       |
# |    time_elapsed       | 782        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -73.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | -352       |
# |    reward             | 0.98401374 |
# |    std                | 1.05       |
# |    value_loss         | 28.4       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 502        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 8800       |
# |    time_elapsed       | 791        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -73.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | -288       |
# |    reward             | -5.3117356 |
# |    std                | 1.05       |
# |    value_loss         | 15.6       |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 486         |
# | time/                 |             |
# |    fps                | 55          |
# |    iterations         | 8900        |
# |    time_elapsed       | 800         |
# |    total_timesteps    | 44500       |
# | train/                |             |
# |    entropy_loss       | -73.5       |
# |    explained_variance | -0.0545     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8899        |
# |    policy_loss        | -132        |
# |    reward             | -0.89441884 |
# |    std                | 1.05        |
# |    value_loss         | 5           |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 486       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 9000      |
# |    time_elapsed       | 809       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -73.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -143      |
# |    reward             | 1.5242691 |
# |    std                | 1.06      |
# |    value_loss         | 5.06      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 486       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 9100      |
# |    time_elapsed       | 818       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -73.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -7.4      |
# |    reward             | 0.1493268 |
# |    std                | 1.06      |
# |    value_loss         | 0.103     |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 486        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9200       |
# |    time_elapsed       | 826        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -73.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | -415       |
# |    reward             | -5.7288527 |
# |    std                | 1.06       |
# |    value_loss         | 34.1       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 486        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9300       |
# |    time_elapsed       | 835        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -73.6      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -10.2      |
# |    reward             | -0.5493723 |
# |    std                | 1.06       |
# |    value_loss         | 2.33       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 486        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9400       |
# |    time_elapsed       | 844        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -73.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | -54.3      |
# |    reward             | -1.1055871 |
# |    std                | 1.06       |
# |    value_loss         | 0.9        |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 486         |
# | time/                 |             |
# |    fps                | 55          |
# |    iterations         | 9500        |
# |    time_elapsed       | 854         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -73.7       |
# |    explained_variance | -0.581      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | 41.6        |
# |    reward             | -0.31079936 |
# |    std                | 1.06        |
# |    value_loss         | 0.693       |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 486        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9600       |
# |    time_elapsed       | 863        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -73.7      |
# |    explained_variance | -0.101     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -191       |
# |    reward             | 0.32733575 |
# |    std                | 1.06       |
# |    value_loss         | 6.28       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 465        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9700       |
# |    time_elapsed       | 872        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -73.7      |
# |    explained_variance | -0.603     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 153        |
# |    reward             | -1.5713378 |
# |    std                | 1.06       |
# |    value_loss         | 9.38       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 4.03e+03   |
# |    ep_rew_mean        | 465        |
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 9800       |
# |    time_elapsed       | 882        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -73.6      |
# |    explained_variance | -1.34      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | 128        |
# |    reward             | -0.8079765 |
# |    std                | 1.06       |
# |    value_loss         | 4.22       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 4.03e+03  |
# |    ep_rew_mean        | 465       |
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 9900      |
# |    time_elapsed       | 891       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -73.6     |
# |    explained_variance | -0.481    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | -19.3     |
# |    reward             | 1.0225592 |
# |    std                | 1.06      |
# |    value_loss         | 0.579     |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 4.03e+03    |
# |    ep_rew_mean        | 465         |
# | time/                 |             |
# |    fps                | 55          |
# |    iterations         | 10000       |
# |    time_elapsed       | 899         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -73.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 181         |
# |    reward             | -0.54004645 |
# |    std                | 1.06        |
# |    value_loss         | 7.18        |
# ---------------------------------------

# %% [markdown]
# ## Trade

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 380, **env_kwargs)

df_account_value, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)

df_account_value.to_csv("df_account_value_a2c.csv")
df_actions.to_csv("df_actions_a2c.csv")
# Out:
# hit end!

# %%
df_account_value.head()
# Out:
#          date  account_value
# 0  2018-01-02   1.000000e+06
# 1  2018-01-03   1.001235e+06
# 2  2018-01-04   1.001629e+06
# 3  2018-01-05   1.003857e+06
# 4  2018-01-08   1.003401e+06

# %%
df_actions.head()
# Out:
#             ADM  AIG  AVB  BA  BIO  BLK  CAG  CPB  DHI  DLTR  ...  SYY  UNH  \
# date                                                          ...
# 2018-01-02    0  100  100   0    0    0    0    0    0     9  ...   85   77
# 2018-01-03    0  100  100   0    0    0    0    0    0     9  ...   85   77
# 2018-01-04    0  100  100   0    0    0    0    0    0     9  ...   85   77
# 2018-01-05    0  100  100   0    0    0    0    0    0     9  ...   85   77
# 2018-01-08    0  100  100   0    0    0    0    0    0     9  ...   85   77
#
#             VNO  VRSN  WBA  WEC  WHR  WM  WST  ZBH
# date
# 2018-01-02    0     0  100    0    0  40    0    5
# 2018-01-03    0     0  100    0    0  40    0    5
# 2018-01-04    0     0  100    0    0  40    0    5
# 2018-01-05    0     0  100    0    0  40    0    5
# 2018-01-08    0     0  100    0    0  40    0    5
#
# [5 rows x 50 columns]
